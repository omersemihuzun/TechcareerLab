# %%
import statistics, random

kitaplar = [
    {"isim": "Veri Bilimi 101", "yazar": "Ali", "tur": "Bilim", "satis": 1200, "yil": 2021},
    {"isim": "Python ile Yapay Zeka", "yazar": "Ayşe", "tur": "Bilim", "satis": 950, "yil": 2020},
    {"isim": "İstatistik Temelleri", "yazar": "Ali", "tur": "Akademik", "satis": 700, "yil": 2019},
    {"isim": "Makine Öğrenmesi", "yazar": "Can", "tur": "Bilim", "satis": 1800, "yil": 2022},
    {"isim": "Veri Görselleştirme", "yazar": "Deniz", "tur": "Sanat", "satis": 400, "yil": 2018},
    {"isim": "Matematiksel Modelleme", "yazar": "Ali", "tur": "Akademik", "satis": 1500, "yil": 2021},
    {"isim": "Bilgi Toplumu", "yazar": "Ayşe", "tur": "Sosyal", "satis": 600, "yil": 2022},
    {"isim": "Veri Madenciliği", "yazar": "Can", "tur": "Bilim", "satis": 1100, "yil": 2019},
    {"isim": "Algoritmaların Temelleri", "yazar": "Ece", "tur": "Akademik", "satis": 1300, "yil": 2020},
    {"isim": "Dijital Sanat", "yazar": "Deniz", "tur": "Sanat", "satis": 850, "yil": 2021},
    {"isim": "Sosyolojiye Giriş", "yazar": "Ayşe", "tur": "Sosyal", "satis": 920, "yil": 2023},
    {"isim": "Derin Öğrenme", "yazar": "Mehmet", "tur": "Bilim", "satis": 2000, "yil": 2023},
    {"isim": "Veri Tabanı Sistemleri", "yazar": "Ali", "tur": "Akademik", "satis": 1400, "yil": 2022},
    {"isim": "Yapay Zeka Etiği", "yazar": "Zeynep", "tur": "Sosyal", "satis": 750, "yil": 2021},
    {"isim": "Sanat ve Teknoloji", "yazar": "Deniz", "tur": "Sanat", "satis": 670, "yil": 2020},
    {"isim": "Veri Güvenliği", "yazar": "Mehmet", "tur": "Bilim", "satis": 1650, "yil": 2022},
    {"isim": "Psikoloji Notları", "yazar": "Zeynep", "tur": "Sosyal", "satis": 500, "yil": 2019},
    {"isim": "İleri Matematik", "yazar": "Ece", "tur": "Akademik", "satis": 1550, "yil": 2023},
    {"isim": "Programlama Dilleri", "yazar": "Can", "tur": "Bilim", "satis": 1250, "yil": 2020},
    {"isim": "Veri Etikası", "yazar": "Ayşe", "tur": "Sosyal", "satis": 880, "yil": 2021},
    {"isim": "Robotik Sistemler", "yazar": "Mehmet", "tur": "Bilim", "satis": 1700, "yil": 2021},
    {"isim": "Görsel Programlama", "yazar": "Ece", "tur": "Akademik", "satis": 900, "yil": 2018},
    {"isim": "Modern Sanat Akımları", "yazar": "Deniz", "tur": "Sanat", "satis": 600, "yil": 2019},
    {"isim": "Toplum ve Teknoloji", "yazar": "Zeynep", "tur": "Sosyal", "satis": 1100, "yil": 2020},
    {"isim": "Sinyal İşleme", "yazar": "Ali", "tur": "Akademik", "satis": 1350, "yil": 2022},
    {"isim": "Kuantum Hesaplama", "yazar": "Can", "tur": "Bilim", "satis": 1950, "yil": 2023},
    {"isim": "Sanat Felsefesi", "yazar": "Deniz", "tur": "Sanat", "satis": 720, "yil": 2021},
    {"isim": "Davranış Bilimleri", "yazar": "Ayşe", "tur": "Sosyal", "satis": 810, "yil": 2022},
    {"isim": "Makine Tasarımı", "yazar": "Mehmet", "tur": "Akademik", "satis": 1450, "yil": 2020},
    {"isim": "Bilgisayar Ağları", "yazar": "Ali", "tur": "Bilim", "satis": 1600, "yil": 2019},
    {"isim": "Psikanaliz Kuramları", "yazar": "Zeynep", "tur": "Sosyal", "satis": 560, "yil": 2018},
    {"isim": "Oyun Teorisi", "yazar": "Ece", "tur": "Akademik", "satis": 1200, "yil": 2021},
    {"isim": "Sanat Tarihi", "yazar": "Deniz", "tur": "Sanat", "satis": 980, "yil": 2022},
    {"isim": "Nörobilim", "yazar": "Can", "tur": "Bilim", "satis": 1750, "yil": 2021},
    {"isim": "Kültürel Çalışmalar", "yazar": "Ayşe", "tur": "Sosyal", "satis": 640, "yil": 2019},
    {"isim": "Optimizasyon Yöntemleri", "yazar": "Ali", "tur": "Akademik", "satis": 1420, "yil": 2023},
    {"isim": "Veri İletişimi", "yazar": "Mehmet", "tur": "Bilim", "satis": 1280, "yil": 2018},
    {"isim": "Etik ve Felsefe", "yazar": "Zeynep", "tur": "Sosyal", "satis": 720, "yil": 2022},
    {"isim": "Yapay Sinir Ağları", "yazar": "Ece", "tur": "Bilim", "satis": 1850, "yil": 2023},
    {"isim": "Rönesans Sanatı", "yazar": "Deniz", "tur": "Sanat", "satis": 530, "yil": 2020},
    {"isim": "İşletme Yönetimi", "yazar": "Ayşe", "tur": "Sosyal", "satis": 1050, "yil": 2021},
    {"isim": "Veri Yapıları", "yazar": "Ali", "tur": "Akademik", "satis": 1370, "yil": 2022},
    {"isim": "Modern Fizik", "yazar": "Can", "tur": "Bilim", "satis": 1620, "yil": 2019},
    {"isim": "Çağdaş Sanat", "yazar": "Deniz", "tur": "Sanat", "satis": 880, "yil": 2023},
    {"isim": "Eğitim Psikolojisi", "yazar": "Zeynep", "tur": "Sosyal", "satis": 770, "yil": 2020},
    {"isim": "Kriptografi", "yazar": "Mehmet", "tur": "Bilim", "satis": 1490, "yil": 2022},
    {"isim": "Yapay Zeka Uygulamaları", "yazar": "Ece", "tur": "Bilim", "satis": 1980, "yil": 2021},
    {"isim": "Matematiksel Mantık", "yazar": "Ali", "tur": "Akademik", "satis": 1550, "yil": 2018},
    {"isim": "Toplumsal Değişim", "yazar": "Ayşe", "tur": "Sosyal", "satis": 890, "yil": 2019},
    {"isim": "Bilim Tarihi", "yazar": "Can", "tur": "Bilim", "satis": 1730, "yil": 2023},
    {"isim": "Sanat Psikolojisi", "yazar": "Deniz", "tur": "Sanat", "satis": 690, "yil": 2021},
    {"isim": "Ekonomi Teorileri", "yazar": "Zeynep", "tur": "Sosyal", "satis": 970, "yil": 2022},
    {"isim": "İstatistiksel Öğrenme", "yazar": "Ece", "tur": "Akademik", "satis": 1600, "yil": 2020},
    {"isim": "Bilgisayar Grafikleri", "yazar": "Mehmet", "tur": "Bilim", "satis": 1440, "yil": 2019},
    {"isim": "Postmodern Sanat", "yazar": "Deniz", "tur": "Sanat", "satis": 810, "yil": 2018},
    {"isim": "Toplum ve Kültür", "yazar": "Ayşe", "tur": "Sosyal", "satis": 950, "yil": 2020},
    {"isim": "Sayısal Analiz", "yazar": "Ali", "tur": "Akademik", "satis": 1380, "yil": 2021},
    {"isim": "Bilimsel Araştırma Yöntemleri", "yazar": "Ece", "tur": "Akademik", "satis": 1520, "yil": 2023},
    {"isim": "Sanal Gerçeklik", "yazar": "Can", "tur": "Bilim", "satis": 1800, "yil": 2022},
    {"isim": "Barok Sanat", "yazar": "Deniz", "tur": "Sanat", "satis": 640, "yil": 2019},
    {"isim": "Sosyal Medya Analizi", "yazar": "Zeynep", "tur": "Sosyal", "satis": 1150, "yil": 2021},
    {"isim": "Bilgi Kuramı", "yazar": "Ali", "tur": "Akademik", "satis": 1450, "yil": 2020},
    {"isim": "Makine Öğrenmesi Projeleri", "yazar": "Mehmet", "tur": "Bilim", "satis": 1670, "yil": 2021},
    {"isim": "Modern Drama", "yazar": "Deniz", "tur": "Sanat", "satis": 720, "yil": 2022},
    {"isim": "Toplum Psikolojisi", "yazar": "Ayşe", "tur": "Sosyal", "satis": 930, "yil": 2023}
]


# 1. Fonksiyonlar
def en_cok_satan(kitaplar):
    return max(kitaplar, key=lambda x: x["satis"])

def yazar_satislari(kitaplar):
    sozluk = {}
    for k in kitaplar:
        sozluk[k["yazar"]] = sozluk.get(k["yazar"], 0) + k["satis"]
    return sozluk

# 2. Liste / Küme
turler = set([k["tur"] for k in kitaplar])
fazla_satan = [k["isim"] for k in kitaplar if k["satis"] > 1000]

# 3. Lambda / Filter / Map
yeni_kitaplar = list(filter(lambda x: x["yil"] > 2020, kitaplar))
artirilmis_satislar = list(map(lambda x: x["satis"]*1.1, kitaplar))
sirali = sorted(kitaplar, key=lambda x: x["satis"], reverse=True)

# 4. İstatistiksel Analiz
ortalama = statistics.mean([k["satis"] for k in kitaplar])
std = statistics.stdev([k["satis"] for k in kitaplar])
tur_satislari = {}
for k in kitaplar:
    tur_satislari[k["tur"]] = tur_satislari.get(k["tur"], 0) + k["satis"]
en_cok_satan_tur = max(tur_satislari, key=tur_satislari.get)

# 5. Train/Test
train = random.sample(kitaplar, int(len(kitaplar)*0.7))
test = [k for k in kitaplar if k not in train]
ortalama_train = statistics.mean([k["satis"] for k in train])
test_ustunde = [k["isim"] for k in test if k["satis"] > ortalama_train]

print("En çok satan kitap:", en_cok_satan(kitaplar))
print("Yazar satışları:", yazar_satislari(kitaplar))
print("Türler:", turler)
print("1000’den fazla satanlar:", fazla_satan)
print("2020 sonrası:", [k["isim"] for k in yeni_kitaplar])
print("Satış %10 artırılmış:", artirilmis_satislar)
print("Satışa göre sıralı:", [k["isim"] for k in sirali])
print("Ortalama satış:", ortalama)
print("Standart sapma:", std)
print("En çok satan tür:", en_cok_satan_tur)
print("Train ortalama:", ortalama_train)
print("Test üstünde:", test_ustunde)
# Out:
# En çok satan kitap: {'isim': 'Derin Öğrenme', 'yazar': 'Mehmet', 'tur': 'Bilim', 'satis': 2000, 'yil': 2023}
# Yazar satışları: {'Ali': 14920, 'Ayşe': 8620, 'Can': 13000, 'Deniz': 8490, 'Ece': 11900, 'Mehmet': 12680, 'Zeynep': 6520}
# Türler: {'Sanat', 'Bilim', 'Sosyal', 'Akademik'}
# ...
